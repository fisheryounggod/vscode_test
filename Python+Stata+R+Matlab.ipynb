# %% [markdown]
# # 准备工作

# %% [markdown]
# ## Python 导包

# %%
import numpy as np
import matplotlib.pylab as plt
from scipy import stats
# %matplotlib inline
import ipystata
import rpy2.ipython 
# %load_ext rpy2.ipython

import matlab
import matlab.engine
# Out:
# IPyStata is loaded in batch mode.

# %% [markdown]
# ## 调用stata

# %% [markdown]
# **15测试通过，都可以显示图形。**

# %%
# from ipystata.config import config_stata 
# config_stata("/Applications/Stata15/StataSE.app/Contents/MacOS/stata-se") #Batch mode

# from ipystata.config import config_stata 
# config_stata("/Applications/Stata15/StataSE.app/Contents/MacOS/stataSE", force_batch=True) #automation mode

# %%
import ipystata

# %%
# %%stata
# display "We love Stata&Python!"
# Out:
# We love Stata&Python!

# %%
# %%stata -gr
# sysuse auto.dta
# graph twoway scatter trunk price
# Out:
# (1978 Automobile Data)
#         <iframe
#             width="700"
#             height="400"
#             src="./temp_graph.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 调用R

# %%
# %R print("Hi from R")
# Out:
# [1] "Hi from R"
# array(['Hi from R'], dtype='<U9')

# %%
# %%R -w 500 -h 300
# # 画图
# x = rnorm(1000)
# hist(x,c='gray')

# %%
# %%R -o x,y
# x = rnorm(100)
# y = rnorm(100)

# %%
x = np.array(x)
y = np.array(y)
z = np.random.choice(['r','b'], size=100, replace=True)
plt.show(plt.scatter(x,y,s=80,c=z ,alpha=0.7))

# %%
import numpy as np  
x=np.random.randint(1,10,30)        # 产生 1 到 10 的一个整数型随机数  
print(x)
# Out:
# [5 4 4 5 3 7 3 4 2 6 9 1 8 8 9 4 9 8 2 7 7 9 2 6 1 3 6 1 6 1]

# %%
# %R -i x

# %%
# %R cat(summary(x) )
# Out:
# 1 3 5 5 7 9

# %% [markdown]
# ## 调用Matlab

# %%
import matlab
import matlab.engine

eng = matlab.engine.start_matlab()

# %%
eng.eval('a = pi;',nargout=0)

pa=eng.workspace['a'] #matlab的workspace的变量复制到python变量

pa
# Out:
# ...
# 3.141592653589793

# %% [markdown]
# # 数据处理

# %% [markdown]
# 17没有输出！！！

# %% [markdown]
# ```python
# from ipystata.config import config_stata
# config_stata("/Applications/Stata/StataMP.app/Contents/MacOS/stata-mp") #Batch mode
#
# from ipystata.config import config_stata
# config_stata("/Applications/Stata/StataMP.app/Contents/MacOS/StataMP")
#
# %%stata
# display "We love Stata&Python!"
# ```

# %%
dir(ipystata)

# %%
print(ipystata.__path__)

# %%
# %%stata -o df
# use "/Users/mac/Stata/stata从入门到精通/data/习题1.4.dta",clear
# des

# %%
df

# %%
# %%stata -i df
# reshape long goal,i(name) j(year)

# %%
# %%stata -o df
# use "/Users/mac/Stata/stata从入门到精通/data/案例1.4.dta",clear
# reshape long number,i(region)j(year)
# //将数据进行长短变换
