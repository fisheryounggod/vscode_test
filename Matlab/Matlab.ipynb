% %%
load dji30short  % 读入文件
d = myfts1
candle(d)
% Out:
% ans =
%
%     '9.3.0.713579 (R2017b)'
%
%
% d =
%
%     desc:  DJI30MAR94.dat
%     freq:  Daily (1)
%
%   Columns 1 through 4
%
%     'dates:  (20)'    'Open:  (20)'    'High:  (20)'    'Low:  (20)'
%     '04-Mar-1994'     [ 3.8309e+03]    [ 3.8680e+03]    [3.8005e+03]
%     '07-Mar-1994'     [ 3.8517e+03]    [ 3.8824e+03]    [3.8247e+03]
%     '08-Mar-1994'     [ 3.8585e+03]    [ 3.8816e+03]    [3.8224e+03]
%     '09-Mar-1994'     [ 3.8540e+03]    [ 3.8745e+03]    [3.8179e+03]
%     '10-Mar-1994'     [ 3.8526e+03]    [ 3.8655e+03]    [3.8016e+03]
%     '11-Mar-1994'     [ 3.8326e+03]    [ 3.8728e+03]    [3.8067e+03]
%     '14-Mar-1994'     [ 3.8703e+03]    [ 3.8942e+03]    [3.8360e+03]
%     '15-Mar-1994'     [ 3.8634e+03]    [ 3.8885e+03]    [3.8268e+03]
%     '16-Mar-1994'     [ 3.8510e+03]    [ 3.8795e+03]    [3.8199e+03]
%     '17-Mar-1994'     [ 3.8536e+03]    [ 3.8913e+03]    [3.8217e+03]
%     '18-Mar-1994'     [ 3.8654e+03]    [ 3.9118e+03]    [3.8387e+03]
% ...

% %%
import rpy2.ipython 
%load_ext rpy2.ipython

% %%
%R  plot(rnorm(100)) #Python调用R最为方便

% %%
1+1
% Out:
% ans =
%
%     '9.3.0.713579 (R2017b)'
%
%
% ans =
%
%      2

% %%
x = linspace(-2*pi,2*pi,20);

% %%
sin(x)
% Out:
% ans =
%
%   Columns 1 through 7
%
%     0.0000    0.6142    0.9694    0.9158    0.4759   -0.1646   -0.7357
%
%   Columns 8 through 14
%
%    -0.9966   -0.8372   -0.3247    0.3247    0.8372    0.9966    0.7357
%
%   Columns 15 through 20
%
%     0.1646   -0.4759   -0.9158   -0.9694   -0.6142   -0.0000

% %%
plot(x,sin(x))

% %%
y = P_add(2,3)
% Out:
% ans =
%
%     '9.3.0.713579 (R2017b)'
%
%
% y =
%
%      5

% %%
1+1
% Out:
% ans =
%
%      2
